# %%
#import dependencies 
import pandas as pd
import requests 
import random
import time
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from citipy import citipy

#import 
from api_keys import weather_api_key as api_key

#create output data file
output_data_file = "output_data/cities.csv"

# %%
# List for holding lat_lngs and cities
lat_long = []
cities = []

# Create a set of random lat and lng combinations
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
long = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_long = zip(lat, long)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_long:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
print(cities)
# Out:
# ['necochea', 'chokurdakh', 'new norfolk', 'tyrma', 'busselton', 'mataura', 'dikson', 'ancud', 'tres arroyos', 'jamestown', 'kruisfontein', 'ushuaia', 'beringovskiy', 'namibe', 'punta arenas', 'nueve de julio', 'illoqqortoormiut', 'egvekinot', 'majene', 'yulara', 'mao', 'tumannyy', 'karaidel', 'masuguru', 'jiuquan', 'hobart', 'yichang', 'atuona', 'attawapiskat', 'upernavik', 'zanesville', 'vaini', 'vanimo', 'vao', 'quelimane', 'grand gaube', 'brigantine', 'albany', 'price', 'thompson', 'northam', 'the valley', 'yumen', 'igunga', 'kyaikto', 'lithgow', 'bethel', 'barrow', 'clyde river', 'barentsburg', 'huainan', 'kapaa', 'mahebourg', 'rikitea', 'sao filipe', 'kyren', 'cockburn town', 'muyezerskiy', 'pringsewu', 'esperance', 'half moon bay', 'grindavik', 'butaritari', 'east london', 'vestmanna', 'kilindoni', 'tautira', 'yirol', 'candido de abreu', 'kodiak', 'pisco', 'mar del plata', 'tsihombe', 'san patricio', 'cape town', 'georgetown', 'hirara', 'mys shmidta', 'virginia', 'pangnirtung', 'sungairaya', 'zaozerne', 'severo-kurilsk', 'yellowknife', 'buala', 'sinop', 'sinjar', 'kirgiz-miyaki', 'bambanglipuro', 'belushya guba', 'constitucion', 'yala', 'norwich', 'victoria', 'meulaboh', 'saint-philippe', 'avarua', 'okha', 'mount gambier', 'sistranda', 'monster', 'hilo', 'puerto escondido', 'taolanaro', 'chenzhou', 'maltahohe', 'bluff', 'zyryanka', 'severomorsk', 'lebu', 'port elizabeth', 'kharp', 'boddam', 'kastamonu', 'saint-louis', 'bonthe', 'mangai', 'daru', 'cabras', 'amapa', 'hermanus', 'salalah', 'khatanga', 'okhotsk', 'ruatoria', 'zhigansk', 'bambous virieux', 'kalininsk', 'rath', 'olafsvik', 'kruglolesskoye', 'panjab', 'maceio', 'agapovka', 'fomboni', 'comodoro rivadavia', 'nizhneyansk', 'san jose', 'lompoc', 'havre', 'qostanay', 'myitkyina', 'hay river', 'noumea', 'charters towers', 'itapirapua', 'taltal', 'meyungs', 'tuktoyaktuk', 'belaya gora', 'lima', 'cidreira', 'maracaju', 'tual', 'puerto ayora', 'castro', 'minab', 'flin flon', 'malatya', 'mount isa', 'pevek', 'oussouye', 'takoradi', 'hithadhoo', 'laguna', 'boueni', 'norman wells', 'cabo san lucas', 'estelle', 'qaanaaq', 'almaty', 'wattegama', 'kieta', 'port alfred', 'sawakin', 'el balyana', 'fort nelson', 'arraial do cabo', 'roxana', 'vila franca do campo', 'gilgit', 'rio grande', 'kavaratti', 'moussoro', 'ostrovnoy', 'quatre cocos', 'lagoa', 'angangxi', 'biak', 'ponte nova', 'izhevskoye', 'port hedland', 'umzimvubu', 'samusu', 'nishihara', 'poum', 'tubuala', 'saint george', 'ocean city', 'taoudenni', 'bengkulu', 'sovetsk', 'mazamari', 'nemuro', 'pilar', 'tefe', 'yulin', 'cozumel', 'aksu', 'marzuq', 'tidore', 'tasiilaq', 'zilupe', 'doha', 'tsabong', 'damietta', 'touros', 'cherskiy', 'longhua', 'margate', 'xichang', 'port hardy', 'portmore', 'port lincoln', 'pottsville', 'kaitangata', 'qinhuangdao', 'florenville', 'salinopolis', 'tevriz', 'siocon', 'kirakira', 'morondava', 'sayan', 'halalo', 'kidal', 'alice springs', 'katsuura', 'carmelo', 'altamira', 'narsaq', 'ahipara', 'torbay', 'bredasdorp', 'prado', 'faanui', 'samalaeulu', 'kununurra', 'matamoros', 'palasa', 'rungata', 'krasnaya gora', 'bambari', 'iralaya', 'carnarvon', 'ardistan', 'rapid city', 'palmer', 'teahupoo', 'nanortalik', 'pachino', 'hamilton', 'lata', 'ayios nikolaos', 'chapais', 'kiunga', 'elk point', 'muros', 'anyang', 'amderma', 'ginir', 'flinders', 'vieques', 'hasaki', 'saskylakh', 'gouyave', 'ciudad bolivar', 'san rafael', 'porosozero', 'simao', 'panguipulli', 'simbahan', 'christchurch', 'panapakkam', 'chuy', 'ribeira grande', 'padang', 'sidi ali', 'ust-kulom', 'luwuk', 'koutsouras', 'alofi', 'bonavista', 'nikolskoye', 'ilulissat', 'balotra', 'malumfashi', 'kavieng', 'geraldton', 'provideniya', 'bone', 'beira', 'potrerillos', 'bandiagara', 'santiago', 'saint-pierre', 'port blair', 'miranorte', 'luganville', 'devonport', 'parang', 'buraydah', 'abu kamal', 'sao joao da barra', 'soligalich', 'ponta do sol', 'caravelas', 'college', 'innisfail', 'airai', 'niamey', 'eldorado', 'dalian', 'tiksi', 'luanda', 'ca ...

# %%
# Create base URL for open weather map API call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

name_city = []
clouds = []
countries = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []

# Create record counter initialized at 1.
record = 1

# Print statement for log.
print("Beginning Data Retrieval")
print('-'*25)

# Loop through all cities in cities list.
#Change the variable cities_test to cities to retrieve all cities rather than the test list
for city in cities:
    try:
        response = requests.get(f'{base_url}&q={city}').json()
        name_city.append(response['name'])
        clouds.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        print(f'Processing Record {record} | {city}')
        record += 1
        time.sleep(1.01)
        
    # If no record found for city, then skip.
    except:
        print('City not found.')
    continue
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 | necochea
# Processing Record 2 | chokurdakh
# Processing Record 3 | new norfolk
# Processing Record 4 | tyrma
# Processing Record 5 | busselton
# Processing Record 6 | mataura
# Processing Record 7 | dikson
# Processing Record 8 | ancud
# Processing Record 9 | tres arroyos
# Processing Record 10 | jamestown
# Processing Record 11 | kruisfontein
# Processing Record 12 | ushuaia
# Processing Record 13 | beringovskiy
# Processing Record 14 | namibe
# Processing Record 15 | punta arenas
# Processing Record 16 | nueve de julio
# City not found.
# Processing Record 17 | egvekinot
# Processing Record 18 | majene
# Processing Record 19 | yulara
# Processing Record 20 | mao
# City not found.
# Processing Record 21 | karaidel
# Processing Record 22 | masuguru
# Processing Record 23 | jiuquan
# Processing Record 24 | hobart
# Processing Record 25 | yichang
# Processing Record 26 | atuona
# City not found.
# Processing Record 27 | upernavik
# Processing Record 28 | zanesville
# Processing Record 29 | vaini
# Processing Record 30 | vanimo
# Processing Record 31 | vao
# Processing Record 32 | quelimane
# Processing Record 33 | grand gaube
# Processing Record 34 | brigantine
# Processing Record 35 | albany
# Processing Record 36 | price
# Processing Record 37 | thompson
# Processing Record 38 | northam
# Processing Record 39 | the valley
# Processing Record 40 | yumen
# Processing Record 41 | igunga
# Processing Record 42 | kyaikto
# Processing Record 43 | lithgow
# Processing Record 44 | bethel
# Processing Record 45 | barrow
# Processing Record 46 | clyde river
# City not found.
# Processing Record 47 | huainan
# Processing Record 48 | kapaa
# Processing Record 49 | mahebourg
# Processing Record 50 | rikitea
# Processing Record 51 | sao filipe
# Processing Record 52 | kyren
# Processing Record 53 | cockburn town
# Processing Record 54 | muyezerskiy
# Processing Record 55 | pringsewu
# Processing Record 56 | esperance
# Processing Record 57 | half moon bay
# Processing Record 58 | grindavik
# Processing Record 59 | butaritari
# Processing Record 60 | east london
# Processing Record 61 | vestmanna
# Processing Record 62 | kilindoni
# Processing Record 63 | tautira
# City not found.
# Processing Record 64 | candido de abreu
# Processing Record 65 | kodiak
# Processing Record 66 | pisco
# Processing Record 67 | mar del plata
# City not found.
# Processing Record 68 | san patricio
# Processing Record 69 | cape town
# Processing Record 70 | georgetown
# Processing Record 71 | hirara
# City not found.
# Processing Record 72 | virginia
# Processing Record 73 | pangnirtung
# Processing Record 74 | sungairaya
# Processing Record 75 | zaozerne
# Processing Record 76 | severo-kurilsk
# Processing Record 77 | yellowknife
# Processing Record 78 | buala
# Processing Record 79 | sinop
# Processing Record 80 | sinjar
# Processing Record 81 | kirgiz-miyaki
# Processing Record 82 | bambanglipuro
# City not found.
# Processing Record 83 | constitucion
# Processing Record 84 | yala
# Processing Record 85 | norwich
# Processing Record 86 | victoria
# Processing Record 87 | meulaboh
# Processing Record 88 | saint-philippe
# Processing Record 89 | avarua
# Processing Record 90 | okha
# Processing Record 91 | mount gambier
# Processing Record 92 | sistranda
# Processing Record 93 | monster
# Processing Record 94 | hilo
# Processing Record 95 | puerto escondido
# City not found.
# Processing Record 96 | chenzhou
# Processing Record 97 | maltahohe
# Processing Record 98 | bluff
# Processing Record 99 | zyryanka
# Processing Record 100 | severomorsk
# Processing Record 101 | lebu
# Processing Record 102 | port elizabeth
# Processing Record 103 | kharp
# Processing Record 104 | boddam
# Processing Record 105 | kastamonu
# Processing Record 106 | saint-louis
# Processing Record 107 | bonthe
# Processing Record 108 | mangai
# Processing Record 109 | daru
# Processing Record 110 | cabras
# Processing Record 111 | amapa
# Processing Record 112 | hermanus
# Processing Record 113 | salalah
# Processing Record 114 | khatanga
# Processing Record 115 | okhotsk
# City not found.
# Processing Record 116 | zhigansk
# Processing Record 117 | bambous virieux
# Processing Record 118 | kalininsk
# Processing Record 119 | rath
# Processing Record 120 | olafsvik
# Processing Record 121 | kruglolesskoye
# Processing Record 122 | panjab
# Processing Record 123 | maceio
# Processing Record 124 | agapovka
# Processing Record 125 | fomboni
# Processing Record 126 | comodoro rivadavia
# City not found.
# Processing Record 127 | san jose
# Processing Record 128 | lompoc
# Processing Record 129 | havre
# Processing Record 130 | qostanay
# Processing Record 131 | myitkyina
# Processing Record 132 | hay river
# Processing Record 133 | noumea
# Processing Record 134 | charters towers
# Processing Record 135 | itapirapua
# Processing Record 136 | taltal
# City not found.
# Processing Record 137 | tuktoyaktuk
# Processing Record 138 | belaya gora
# Processing Record 139 | lima
# Processing Record 140 | cidreira
# Processing Record 141 | maracaju
# Processing Record 142 | tual
# Processing Record 143 | puerto ayora
# Processing Record 144 | castro
# Processing Record 145 | minab
# Processing Record 146 | flin flon
# Processing Record 147 | malatya
# Processing Record 148 | mount isa
# Processing Record 149 | pevek
# Processing Record 150 | oussouye
# Processing Record 151 | takoradi
# Processing Record 152 | hithadhoo
# Processing Record 153 | laguna
# Processing Record 154 | boueni
# Processing Record 155 | norman wells
# Processing Record 156 | cabo san lucas
# Processing Record 157 | estelle
# Processing Record 158 | qaanaaq
# Processing Record 159 | almaty
# Processing Record 160 | wattegama
# Processing Record 161 | kieta
# Processing Record 162 | port alfred
# Processing Record 163 | sawakin
# City not found.
# Processing Record 164 | fort nelson
# Processing Record 165 | arraial do cabo
# Processing Record 166 | roxana
# Processing Record 167 | vila franca do campo
# Processing Record 168 | gilgit
# Processing Record 169 | rio grande
# Processing Record 170 | kavaratti
# Processing Record 171 | moussoro
# Processing Record 172 | ostrovnoy
# Processing Record 173 | quatre cocos
# Processing Record 174 | lagoa
# City not found.
# Processing Record 175 | biak
# Processing Record 176 | ponte nova
# Processing Record 177 | izhevskoye
# Processing Record 178 | port hedland
# City not found.
# City not found.
# Processing Record 179 | nishihara
# Processing Record 180 | poum
# Processing Record 181 | tubuala
# Processing Record 182 | saint george
# Processing Record 183 | ocean city
# Processing Record 184 | taoudenni
# Processing Record 185 | bengkulu
# Processing Record 186 | sovetsk
# Processing Record 187 | mazamari
# Processing Record 188 | nemuro
# Processing Record 189 | pilar
# Processing Record 190 | tefe
# Processing Record 191 | yulin
# Processing Record 192 | cozumel
# Processing Record 193 | aksu
# Processing Record 194 | marzuq
# City not found.
# Processing Record 195 | tasiilaq
# Processing Record 196 | zilupe
# Processing Record 197 | doha
# Processing Record 198 | tsabong
# Processing Record 199 | damietta
# Processing Record 200 | touros
# Processing Record 201 | cherskiy
# Processing Record 202 | longhua
# Processing Record 203 | margate
# Processing Record 204 | xichang
# Processing Record 205 | port hardy
# Processing Record 206 | portmore
# Processing Record 207 | port lincoln
# Processing Record 208 | pottsville
# Processing Record 209 | kaitangata
# Processing Record 210 | qinhuangdao
# Processing Record 211 | florenville
# Processing Record 212 | salinopolis
# Processing Record 213 | tevriz
# Processing Record 214 | siocon
# Processing Record 215 | kirakira
# Processing Record 216 | morondava
# Processing Record 217 | sayan
# City not found.
# Processing Record 218 | kidal
# Processing Record 219 | alice springs
# Processing Record 220 | katsuura
# Processing Record 221 | carmelo
# Processing Record 222 | altamira
# Processing Record 223 | narsaq
# Processing Record 224 | ahipara
# Processing Record 225 | torbay
# Processing Record 226 | bredasdorp
# Processing Record 227 | prado
# Processing Record 228 | faanui
# City not found.
# Processing Record 229 | kununurra
# Processing Record 230 | matamoros
# Processing Record 231 | palasa
# City not found.
# Processing Record 232 | krasnaya gora
# Processing Record 233 | bambari
# Processing Record 234 | iralaya
# Processing Record 235 | carnarvon
# City not found.
# Processing Record 236 | rapid city
# Processing Record 237 | palmer
# Processing Record 238 | teahupoo
# Processing Record 239 | nanortalik
# Processing Record 240 | pachino
# Processing Record 241 | hamilton
# Processing Record 242 | lata
# Processing Record 243 | ayios nikolaos
# Processing Record 244 | chapais
# Processing Record 245 | kiunga
# Processing Record 246 | elk point
# Processing Record 247 | muros
# Processing Record 248 | anyang
# City not found.
# Processing Record 249 | ginir
# Processing Record 250 | flinders
# Processing Record 251 | vieques
# Processing Record 252 | hasaki
# Processing Record 253 | saskylakh
# Processing Record 254 | gouyave
# Processing Record 255 | ciudad bolivar
# Processing Record 256 | san rafael
# Processing Record 257 | porosozero
# Processing Record 258 | simao
# Processing Record 259 | panguipulli
# Processing Record 260 | simbahan
# Processing Record 261 | christchurch
# City not found.
# Processing Record 262 | chuy
# Processing Record 263 | ribeira grande
# Processing Record 264 | padang
# Processing Record 265 | sidi ali
# Processing Record 266 | ust-kulom
# Processing Record 267 | luwuk
# Processing Record 268 | koutsouras
# Processing Record 269 | alofi
# Processing Record 270 | bonavista
# Processing Record 271 | nikolskoye
# Processing Record 272 | ilulissat
# Processing Record 273 | balotra
# Processing Record 274 | malumfashi
# Processing Record 275 | kavieng
# Processing Record 276 | geraldton
# Processing Record 277 | provideniya
# Processing Record 278 | bone
# Processing Record 279 | beira
# Processing Record 280 | potrerillos
# Processing Record 281 | bandiagara
# Processing Record 282 | santiago
# Processing Record 283 | saint-pierre
# Processing Record 284 | port blair
# City not found.
# Processing Record 285 | luganville
# Processing Record 286 | devonport
# Processing Record 287 | parang
# Processing Record 288 | buraydah
# Processing Record 289 | abu kamal
# Processing Record 290 | sao joao da barra
# Processing Record 291 | soligalich
# Processing Record 292 | ponta do sol
# Processing Record 293 | caravelas
# Processing Record 294 | college
# Processing Record 295 | innisfail
# Processing Record 296 | airai
# Processing Record 297 | niamey
# Processing Record 298 | eldorado
# Processing Record 299 | dalian
# Processing Record 300 | tiksi
# Processing Record 301 | luanda
# Processing Record 302 | cajimos
# Processing Record 303 | yelizovo
# Processing Record 304 | ahuimanu
# City not found.
# Processing Record 305 | isangel
# Processing Record 306 | sinazongwe
# Processing Record 307 | olinda
# Processing Record 308 | rio gallegos
# Processing Record 309 | tilichiki
# City not found.
# Processing Record 310 | burnie
# Processing Record 311 | mehamn
# Processing Record 312 | marsa matruh
# Processing Record 313 | gamba
# Processing Record 314 | robertsport
# Processing Record 315 | lobito
# Processing Record 316 | lavrentiya
# Processing Record 317 | weihe
# Processing Record 318 | thongwa
# Processing Record 319 | sur
# Processing Record 320 | palagonia
# Processing Record 321 | souillac
# Processing Record 322 | bosaso
# Processing Record 323 | naze
# Processing Record 324 | guaira
# Processing Record 325 | snyder
# Processing Record 326 | mlonggo
# Processing Record 327 | vostok
# Processing Record 328 | lorengau
# Processing Record 329 | suwalki
# Processing Record 330 | nikki
# Processing Record 331 | neiafu
# Processing Record 332 | windsor
# Processing Record 333 | bani walid
# Processing Record 334 | pombal
# Processing Record 335 | tingo maria
# Processing Record 336 | koulikoro
# Processing Record 337 | uyuni
# Processing Record 338 | san quintin
# Processing Record 339 | campo maior
# City not found.
# Processing Record 340 | dingle
# Processing Record 341 | antalaha
# Processing Record 342 | cayenne
# Processing Record 343 | tateyama
# Processing Record 344 | portland
# Processing Record 345 | rocha
# Processing Record 346 | alta floresta
# Processing Record 347 | labrea
# Processing Record 348 | tambacounda
# Processing Record 349 | nettuno
# City not found.
# Processing Record 350 | polyarnyye zori
# Processing Record 351 | palaikastron
# Processing Record 352 | claresholm
# Processing Record 353 | lac du bonnet
# Processing Record 354 | san ignacio
# Processing Record 355 | leningradskiy
# Processing Record 356 | tessalit
# Processing Record 357 | kismayo
# Processing Record 358 | matagami
# Processing Record 359 | teguldet
# City not found.
# Processing Record 360 | longyearbyen
# Processing Record 361 | vardo
# Processing Record 362 | guerrero negro
# Processing Record 363 | luorong
# Processing Record 364 | chancay
# Processing Record 365 | namatanai
# Processing Record 366 | faya
# Processing Record 367 | kefamenanu
# Processing Record 368 | merauke
# Processing Record 369 | san cristobal
# Processing Record 370 | yankton
# Processing Record 371 | acajutla
# Processing Record 372 | andenes
# Processing Record 373 | bubaque
# City not found.
# Processing Record 374 | oranjestad
# Processing Record 375 | lensk
# Processing Record 376 | mayor pablo lagerenza
# Processing Record 377 | alpena
# Processing Record 378 | gazojak
# Processing Record 379 | ca mau
# Processing Record 380 | acapulco
# City not found.
# Processing Record 381 | nome
# Processing Record 382 | bandarbeyla
# Processing Record 383 | wanning
# Processing Record 384 | bathsheba
# Processing Record 385 | luderitz
# Processing Record 386 | korla
# Processing Record 387 | havelock
# Processing Record 388 | tuatapere
# Processing Record 389 | umtata
# Processing Record 390 | tibacuy
# Processing Record 391 | foumban
# Processing Record 392 | gimli
# Processing Record 393 | migori
# Processing Record 394 | aquiraz
# Processing Record 395 | dhidhdhoo
# Processing Record 396 | pirovskoye
# City not found.
# Processing Record 397 | kribi
# Processing Record 398 | berdsk
# Processing Record 399 | la orilla
# Processing Record 400 | lasa
# Processing Record 401 | labuhan
# Processing Record 402 | ellensburg
# Processing Record 403 | ust-ishim
# Processing Record 404 | richards bay
# Processing Record 405 | port-gentil
# Processing Record 406 | ayan
# Processing Record 407 | nkayi
# Processing Record 408 | mahibadhoo
# Processing Record 409 | beroroha
# Processing Record 410 | paka
# Processing Record 411 | merrill
# Processing Record 412 | aykhal
# Processing Record 413 | mabaruma
# Processing Record 414 | san francisco
# Processing Record 415 | surt
# City not found.
# Processing Record 416 | ivot
# Processing Record 417 | ancona
# Processing Record 418 | asfi
# City not found.
# Processing Record 419 | maragogi
# Processing Record 420 | vestmannaeyjar
# Processing Record 421 | tucuman
# Processing Record 422 | port moresby
# Processing Record 423 | bandar-e anzali
# Processing Record 424 | siva
# Processing Record 425 | bharatpur
# Processing Record 426 | laurel
# Processing Record 427 | nicoya
# Processing Record 428 | grand-santi
# Processing Record 429 | klaksvik
# Processing Record 430 | morwell
# Processing Record 431 | granollers
# Processing Record 432 | adrar
# Processing Record 433 | watsa
# Processing Record 434 | mildura
# City not found.
# Processing Record 435 | el retorno
# Processing Record 436 | terrace bay
# Processing Record 437 | walvis bay
# Processing Record 438 | vikhorevka
# Processing Record 439 | portobelo
# Processing Record 440 | hoa binh
# Processing Record 441 | coquimbo
# Processing Record 442 | arlit
# Processing Record 443 | umm lajj
# Processing Record 444 | luba
# Processing Record 445 | yablonovo
# Processing Record 446 | goldsboro
# Processing Record 447 | saint-francois
# Processing Record 448 | vermilion
# Processing Record 449 | pemberton
# Processing Record 450 | pacific grove
# Processing Record 451 | gaoua
# Processing Record 452 | nguruka
# Processing Record 453 | andilamena
# Processing Record 454 | chukhloma
# Processing Record 455 | hofn
# Processing Record 456 | itarema
# Processing Record 457 | haifa
# Processing Record 458 | saldanha
# Processing Record 459 | tabas
# Processing Record 460 | formosa do rio preto
# Processing Record 461 | high level
# Processing Record 462 | azoyu
# Processing Record 463 | muisne
# Processing Record 464 | mwanza
# Processing Record 465 | fairbanks
# Processing Record 466 | uglovskoye
# Processing Record 467 | meadow lake
# Processing Record 468 | ponta delgada
# Processing Record 469 | chimbote
# Processing Record 470 | kaeo
# Processing Record 471 | carballo
# Processing Record 472 | saint-paul
# Processing Record 473 | lubango
# Processing Record 474 | korcula
# Processing Record 475 | codrington
# Processing Record 476 | hovd
# Processing Record 477 | hawera
# Processing Record 478 | krasnoselkup
# Processing Record 479 | los llanos de aridane
# Processing Record 480 | khasan
# Processing Record 481 | kyzyl-suu
# Processing Record 482 | praia da vitoria
# Processing Record 483 | fortuna
# Processing Record 484 | thoen
# Processing Record 485 | severnyy
# Processing Record 486 | verkhnevilyuysk
# Processing Record 487 | puerto leguizamo
# Processing Record 488 | zeya
# City not found.
# Processing Record 489 | waddan
# Processing Record 490 | neyshabur
# Processing Record 491 | shingu
# Processing Record 492 | kangaatsiaq
# Processing Record 493 | saint anthony
# Processing Record 494 | broome
# Processing Record 495 | zabid
# Processing Record 496 | port-cartier
# Processing Record 497 | vozhega
# Processing Record 498 | kijang
# Processing Record 499 | havre-saint-pierre
# Processing Record 500 | sabancuy
# Processing Record 501 | mayenne
# Processing Record 502 | kahului
# Processing Record 503 | rockland
# Processing Record 504 | sretensk
# Processing Record 505 | strezhevoy
# Processing Record 506 | kaseda
# Processing Record 507 | lakatoro
# Processing Record 508 | sioux lookout
# Processing Record 509 | rurrenabaque
# Processing Record 510 | mwaro
# Processing Record 511 | ottumwa
# City not found.
# Processing Record 512 | talnakh
# Processing Record 513 | mahon
# Processing Record 514 | utrera
# Processing Record 515 | lander
# Processing Record 516 | sotnikovo
# Processing Record 517 | eureka
# Processing Record 518 | deputatskiy
# Processing Record 519 | buluang
# Processing Record 520 | moissala
# Processing Record 521 | altus
# Processing Record 522 | altay
# Processing Record 523 | kansanshi
# Processing Record 524 | srivardhan
# Processing Record 525 | nanning
# Processing Record 526 | hami
# Processing Record 527 | parral
# Processing Record 528 | kenitra
# Processing Record 529 | ucluelet
# Processing Record 530 | odesskoye
# Processing Record 531 | zaraza
# Processing Record 532 | cape canaveral
# Processing Record 533 | bar-le-duc
# Processing Record 534 | henties bay
# Processing Record 535 | benghazi
# Processing Record 536 | jumla
# Processing Record 537 | raisinghnagar
# Processing Record 538 | aripuana
# Processing Record 539 | puerto ayacucho
# Processing Record 540 | springbok
# Processing Record 541 | nealtican
# Processing Record 542 | san vicente
# Processing Record 543 | porto novo
# Processing Record 544 | trairi
# Processing Record 545 | redcliffe
# City not found.
# Processing Record 546 | ponnani
# Processing Record 547 | katobu
# Processing Record 548 | caconda
# Processing Record 549 | thunder bay
# Processing Record 550 | san felipe
# Processing Record 551 | rumoi
# Processing Record 552 | venice
# City not found.
# Processing Record 553 | samarai
# Processing Record 554 | coromandel
# Processing Record 555 | cordoba
# Processing Record 556 | westport
# Processing Record 557 | hanzhong
# Processing Record 558 | santiago del estero
# Processing Record 559 | mozarlandia
# Processing Record 560 | santa cruz do rio pardo
# Processing Record 561 | garden city
# Processing Record 562 | roald
# Processing Record 563 | murgab
# Processing Record 564 | san ramon de la nueva oran
# Processing Record 565 | tecoanapa
# Processing Record 566 | dunedin
# Processing Record 567 | santa isabel do rio negro
# Processing Record 568 | chicama

# %%
#API calls

# Create values dictionary from API call lists.
weatherdata = {
    'City': name_city,
    'Cloudiness': clouds,
    'Country': countries,
    'Date': dates,
    'Humidity': humidities,
    'Lat': lats,
    'Lng': lngs,
    'Max Temperature': max_temps,
    'Wind Speed': wind_speeds
}

# Create new DF for values in dictionary.
weather_df = pd.DataFrame(weatherdata)
#output to csv
weather_df.to_csv('weatherdata.csv')

# %%
# Check to see that weather_df actually contains needed data
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0     Necochea          96      AR  1613317472        66 -38.5473  -58.7368
# 1   Chokurdakh         100      RU  1613317463        86  70.6333  147.9167
# 2  New Norfolk         100      AU  1613317472        65 -42.7826  147.0587
# 3        Tyrma           8      RU  1613317476        88  50.0833  132.1667
# 4    Busselton          95      AU  1613317477        85 -33.6500  115.3333
#
#    Max Temperature  Wind Speed
# 0            74.77        7.25
# 1           -11.96        9.60
# 2            61.00        1.99
# 3           -11.97        2.06
# 4            72.00        7.70

# %%
# Create scatter plot for Lat vs Max Temp.
plt.scatter(weather_df['Lat'], weather_df['Max Temperature'], marker='o', s=20, c='r', edgecolors='black', alpha=.75)

# Format axis/labels.
plt.title('Temperature (F) vs. Latitude')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure.
plt.savefig('Max_Temp_vs_Lat.png')
plt.show()

# %%
# Create scatter plot for Lat vs Humidity.
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker='o', s=20, c='b', edgecolors='black', alpha=.75)

# Format axis and labels.
plt.title('Humidity (%) vs. Latitude')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure.
plt.savefig('Humidity_vs_Lat.png')

plt.show()

# %%
# Create scatter plot for Lat vs Cloudiness.
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker='o', s=20, c='g', edgecolors='black', alpha=.75)

# Format axis and labels.
plt.title('Cloudiness (%) vs. Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure.
plt.savefig('Cloudiness_vs_Lat.png')
plt.show()

# %%
# Create scatter plot for Lat vs Wind Speed.
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker='o', s=20, c='black', edgecolors='black', alpha=.75)

# Format axis and labels.
plt.title('Wind Speed (mph) vs. Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure.
plt.savefig('Windspeed_vs_Lat.png')
plt.show()

# %%
#import additional dependencies

from scipy.stats import linregress
from pprint import pprint

# %%
northern = weather_df.loc[weather_df["Lat"] >= 0.0]
northern.reset_index(inplace=True)

southern = weather_df.loc[weather_df["Lat"] < 0.0]
southern.reset_index(inplace=True)

# %%
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"fig{ifig}.png")
    plt.show()

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude

xlbl = "Lat"
ylbl = "Max Temperature"
lblpos = (40,80)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8706680304356441

# %%
# Southern Hemisphere - Temperature (F) vs. Latitude

xlbl = "Lat"
ylbl = "Max Temperature"
lblpos = (-25,45)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.6176403535944229

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude

xlbl = "Lat"
ylbl = "Humidity"
lblpos = (45,20)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.38320758424789636

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude

xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-56,18)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.13011573013241326

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (40,30)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.3211569109132623

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,20)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.2595945511948208

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.0743373455708416

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude
xlbl = "Lat"
ylbl = "Wind Speed"
title = 'Southern Hemisphere - Wind Speed (mph) vs. Latitude'
lblpos = (-25,23)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.14663546449672182
